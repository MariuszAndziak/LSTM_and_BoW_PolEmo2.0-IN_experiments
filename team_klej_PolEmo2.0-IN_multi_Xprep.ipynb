# %% [markdown]
# # ❇️LSTM #

# %% [markdown]
# ##  ` 👉Opis zadania` ###

# %% [markdown]
# ## 🇵🇱 Zadanie 2.2.8** (opcjonalnie)
#
# Nowy zbiór z `KLEJ` - [PolEmo2.0-IN](https://clarin-pl.eu/dspace/handle/11321/710). To zestaw recenzji online z dziedziny medycyny i hoteli. Zadaniem jest przewidzenie sentymentu recenzji.
#
# * input: `../input/klej/klej_polemo2.0-in/train.tsv`
# * models: `../models/word2vec/klej_polemo2.0-in_train`

# %% [markdown]
# ##  ` 👉Import bibliotek` ###

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import tensorflow as tf

import random
import os

from gensim.utils import simple_preprocess
import tensorflow.keras.preprocessing.text as kpt 

from tensorflow.keras.preprocessing import sequence
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, LSTM, Dense, Bidirectional, Flatten
from keras.layers import Dropout

from itertools import product
import mlflow
import time
import datetime
import warnings

import team_helper as th
from team_helper import recall, precision, f1, get_y
from team_helper import random_polemo2_opinion as random_opinion

# %% [markdown]
# ##  ` 👉Usunięcie niepotrzebnych ostrzeżeń + ustawienie mlflow` ###

# %%
warnings.filterwarnings('ignore', category=DeprecationWarning)
warnings.filterwarnings('ignore', category=RuntimeWarning)

# %%
mlflow.set_tracking_uri("file:///home/jovyan/nlp2/shared-mlruns/team-three/mariusz")

# %% [markdown]
# ##  ` 👉Próba zapewnienia powtarzalności eksperymentu` ###

# %%
seed_value= 0
os.environ['PYTHONHASHSEED']=str(seed_value)
random.seed(seed_value)
np.random.seed(seed_value)
tf.random.set_seed(seed_value)
tf.compat.v1.set_random_seed(seed_value)

# %% [markdown]
# ##  ` 👉Eksploracja zbioru` ###

# %%
df = pd.read_csv('../input/klej/klej_polemo2.0-in/train.tsv', sep='\t')

# %%
df
# Out:
#                                                sentence                 target
# 0     Super lekarz i człowiek przez duże C . Bardzo ...   __label__meta_plus_m
# 1     Bardzo olewcze podejscie do pacjenta . Przypro...  __label__meta_minus_m
# 2     Lekarz zalecił mi kurację alternatywną do doty...      __label__meta_amb
# 3      Konsumenci oczywiście kierują się ceną . Te l...     __label__meta_zero
# 4     Pani Doktor Iwona jest profesjonalistką w każd...   __label__meta_plus_m
# ...                                                 ...                    ...
# 5739  Centralne skrzydło jest jednokondygnacyjne , z...     __label__meta_zero
# 5740  Ogólnie w hotelu panuje balagan informacyjny -...  __label__meta_minus_m
# 5741  Przybyli śmy z rodziną na krotki wypoczynek . ...      __label__meta_amb
# 5742  Opinię może wyrazić dzisiaj każdy i jest to je...     __label__meta_zero
# 5743  Apartamenty w wielkim budynku , z basenem , w ...      __label__meta_amb
#
# [5744 rows x 2 columns]

# %%
df['target'].value_counts(normalize=True)
# Out:
# __label__meta_minus_m    0.380223
# __label__meta_plus_m     0.270369
# __label__meta_amb        0.181929
# __label__meta_zero       0.167479
# Name: target, dtype: float64

# %% [markdown]
# ##  ` 👉Wyodrębnienie zmiennych i preprocessing` ###

# %%
X_oryg = df['sentence'].map(th.simple_tokens)
Xprep = df['sentence'].map(th.preprocessing).map(simple_preprocess)

y = get_y(df, 'target')

# %% [markdown]
# ##  ` 👉Wybór parametrów do eksperymentu` ###

# %%
EXP_NAME = 'LSTM_polemo2_0_IN_X_prep'
SELECTED_X = Xprep

# jak duży ma być słownik
num_words_list = [500, 300] 

# do ilu słów mamy uciąć daną recenzję
maxlens_list = [60, 50, 40, 10]

# ile ma być dwukierunkowych warstw w LSTM
nobs_list = [0, 1 , 2] 

# jak długi wektor ma reprezentować dane słowo
embedding_vector_lengths_list = [400, 500] 

# liczba jednostek
units_list = [32, 64]

# liczba epok
epochs_list = [10]

# %% [markdown]
# ##  ` 👉Przydatne funkcje` ###

# %%
def make_sequence(inputX, num_words, maxlen):
    tokenizer = kpt.Tokenizer(num_words)
    tokenizer.fit_on_texts(inputX) 
    sequences = tokenizer.texts_to_sequences(inputX) 
    X = sequence.pad_sequences(sequences, maxlen, padding='post', truncating='post')
    return X

# %%
def get_multi_LSTM(nob, unit, num_words, embedding_vector_length, maxlen):
    if nob == 0:
        model = Sequential([
            Embedding(num_words, embedding_vector_length, input_length=maxlen),
            Dropout(0.9),
            LSTM(unit),
            Dense(y.shape[1], activation='softmax')
        ])
    if nob == 1:
        model = Sequential([
            Embedding(num_words, embedding_vector_length, input_length=maxlen),
            Dropout(0.9),
            Bidirectional(LSTM(unit, dropout=0.5)),
            #Bidirectional(LSTM(unit)),
            #Dropout(0.5),
            Dense(y.shape[1], activation='softmax')
        ])
    if nob == 2:
        model = Sequential([
            Embedding(num_words, embedding_vector_length, input_length=maxlen),
            Dropout(0.9),
            Bidirectional(LSTM(unit, dropout=0.5, return_sequences=True)),
            Bidirectional(LSTM(unit, dropout=0.5)),
            #Bidirectional(LSTM(unit, return_sequences=True)),
            #Bidirectional(LSTM(unit)),
            #Dropout(0.5),
            Dense(y.shape[1], activation='softmax')
        ])
    return model

# %% [markdown]
# ##  ` 👉Eksperyment` ###

# %%
params_cnt = len(num_words_list)*\
len(maxlens_list)*\
len(nobs_list)*\
len(embedding_vector_lengths_list)*\
len(units_list)*len(epochs_list)

exp_start = datetime.datetime.now()

for n,(num_words, maxlen, nob, embedding_vector_length, unit, epoch) in \
enumerate(product(num_words_list, maxlens_list, nobs_list, embedding_vector_lengths_list, units_list, epochs_list),1):
    
    X = make_sequence(SELECTED_X, num_words, maxlen)

    model_str = f'Embedding (max_top_words={num_words}, max_opinion_length={maxlen}, ' \
    + f'embedding_vector_lengths={embedding_vector_length}, units={unit}, epochs={epoch}, nobs={nob})'

    print(f'{n}/{params_cnt}')
    print(model_str)

    with mlflow.start_run(experiment_id=th._eid(EXP_NAME), run_name=model_str):

        model = get_multi_LSTM(nob, unit, num_words, embedding_vector_length, maxlen)

        start = time.time()
        model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy', precision, recall, f1])
        history = model.fit( 
            X, y,
            epochs=epoch, batch_size=256,
            validation_split=0.1,
            #callbacks=[PlotLossesKeras()],
            verbose=0)
        end = time.time()
        
        print('train_f1_curr = ', round(history.history['f1'][-1],3))
        print('train_f1_max = ', round(max(history.history['f1']),3))
        print('val_f1_curr = ', round(history.history['val_f1'][-1],3))
        print('val_f1_max = ',round(max(history.history['val_f1']),3))
        
        print('time: ',round((end-start),2))
        print('-'*10)

        # log params
        mlflow.log_param('model', model_str)
        mlflow.log_param('max_opinion_length', maxlen)
        mlflow.log_param('max_top_words', num_words)
        mlflow.log_param('epoch', epoch)
        mlflow.log_param('unit', unit)
        mlflow.log_param('nob', nob)
        
        # log metrics
        mlflow.log_metric('train_accuracy_curr', history.history['accuracy'][-1])
        mlflow.log_metric('train_accuracy_max', max(history.history['accuracy']))
        mlflow.log_metric('val_accuracy_curr', history.history['val_accuracy'][-1])
        mlflow.log_metric('val_accuracy_max', max(history.history['val_accuracy']))
        
        mlflow.log_metric('train_precision_curr', history.history['accuracy'][-1])
        mlflow.log_metric('train_precision_max', max(history.history['precision']))
        mlflow.log_metric('val_precision_curr', history.history['val_precision'][-1])
        mlflow.log_metric('val_precision_max', max(history.history['val_precision']))

        mlflow.log_metric('train_recall_curr', history.history['recall'][-1])
        mlflow.log_metric('train_recall_max', max(history.history['recall']))
        mlflow.log_metric('val_recall_curr', history.history['val_recall'][-1])
        mlflow.log_metric('val_recall_max', max(history.history['val_recall']))
        
        mlflow.log_metric('train_f1_curr', history.history['f1'][-1])
        mlflow.log_metric('train_f1_max', max(history.history['f1']))
        mlflow.log_metric('val_f1_curr', history.history['val_f1'][-1])
        mlflow.log_metric('val_f1_max', max(history.history['val_f1']))
        
        mlflow.log_metric('loss', history.history['loss'][-1])
        mlflow.log_metric('calc_time', (end-start))
        

        # log artifacts
        fig = plt.figure()
        plt.plot(history.history['f1'])
        plt.plot(history.history['val_f1'])
        plt.title('model f1')
        plt.ylabel('f1')
        plt.xlabel('epoch')
        plt.legend(['train', 'valid'], loc='best')
        mlflow.log_figure(fig, "f1-plot.png")
        
        fig2 = plt.figure()
        plt.plot(history.history['loss'])
        plt.plot(history.history['val_loss'])
        plt.title('model loss')
        plt.ylabel('loss')
        plt.xlabel('epoch')
        plt.legend(['train', 'valid'], loc='best')
        mlflow.log_figure(fig2, "loss-plot.png")
        
        
exp_end = datetime.datetime.now()
print('='*10)
print(f'Start of experiment: {exp_start}')
print(f'End of experiment: {exp_end}')
th.calculate_delta((exp_end-exp_start))

dfruns = mlflow.search_runs(experiment_ids=[th._eid(EXP_NAME)])
# Out:
# 1/96
# Embedding (max_top_words=500, max_opinion_length=60, embedding_vector_lengths=400, units=32, epochs=10, nobs=0)
# train_f1_curr =  0.722
# train_f1_max =  0.722
# val_f1_curr =  0.684
# val_f1_max =  0.684
# time:  164.3
# ----------
# 2/96
# Embedding (max_top_words=500, max_opinion_length=60, embedding_vector_lengths=400, units=64, epochs=10, nobs=0)
# train_f1_curr =  0.717
# train_f1_max =  0.717
# val_f1_curr =  0.679
# val_f1_max =  0.68
# time:  213.53
# ----------
# 3/96
# Embedding (max_top_words=500, max_opinion_length=60, embedding_vector_lengths=500, units=32, epochs=10, nobs=0)
# train_f1_curr =  0.702
# train_f1_max =  0.702
# val_f1_curr =  0.656
# val_f1_max =  0.656
# time:  189.37
# ----------
# 4/96
# Embedding (max_top_words=500, max_opinion_length=60, embedding_vector_lengths=500, units=64, epochs=10, nobs=0)
# train_f1_curr =  0.714
# train_f1_max =  0.719
# val_f1_curr =  0.688
# val_f1_max =  0.693
# time:  245.54
# ----------
# 5/96
# Embedding (max_top_words=500, max_opinion_length=60, embedding_vector_lengths=400, units=32, epochs=10, nobs=1)
# train_f1_curr =  0.716
# train_f1_max =  0.716
# val_f1_curr =  0.714
# val_f1_max =  0.714
# time:  315.95
# ----------
# 6/96
# Embedding (max_top_words=500, max_opinion_length=60, embedding_vector_lengths=400, units=64, epochs=10, nobs=1)
# train_f1_curr =  0.727
# train_f1_max =  0.727
# val_f1_curr =  0.716
# val_f1_max =  0.716
# time:  399.81
# ----------
# 7/96
# Embedding (max_top_words=500, max_opinion_length=60, embedding_vector_lengths=500, units=32, epochs=10, nobs=1)
# train_f1_curr =  0.727
# train_f1_max =  0.727
# val_f1_curr =  0.72
# val_f1_max =  0.72
# time:  341.84
# ----------
# 8/96
# Embedding (max_top_words=500, max_opinion_length=60, embedding_vector_lengths=500, units=64, epochs=10, nobs=1)
# train_f1_curr =  0.738
# train_f1_max =  0.738
# val_f1_curr =  0.727
# val_f1_max =  0.741
# time:  440.38
# ----------
# 9/96
# Embedding (max_top_words=500, max_opinion_length=60, embedding_vector_lengths=400, units=32, epochs=10, nobs=2)
# train_f1_curr =  0.738
# train_f1_max =  0.738
# val_f1_curr =  0.745
# val_f1_max =  0.745
# time:  514.95
# ----------
# 10/96
# Embedding (max_top_words=500, max_opinion_length=60, embedding_vector_lengths=400, units=64, epochs=10, nobs=2)
# train_f1_curr =  0.75
# train_f1_max =  0.75
# val_f1_curr =  0.77
# val_f1_max =  0.77
# time:  696.6
# ----------
# 11/96
# Embedding (max_top_words=500, max_opinion_length=60, embedding_vector_lengths=500, units=32, epochs=10, nobs=2)
# train_f1_curr =  0.735
# train_f1_max =  0.735
# val_f1_curr =  0.738
# val_f1_max =  0.738
# time:  551.86
# ----------
# 12/96
# Embedding (max_top_words=500, max_opinion_length=60, embedding_vector_lengths=500, units=64, epochs=10, nobs=2)
# train_f1_curr =  0.747
# train_f1_max =  0.747
# val_f1_curr =  0.761
# val_f1_max =  0.761
# time:  737.59
# ----------
# 13/96
# Embedding (max_top_words=500, max_opinion_length=50, embedding_vector_lengths=400, units=32, epochs=10, nobs=0)
# train_f1_curr =  0.728
# train_f1_max =  0.728
# val_f1_curr =  0.693
# val_f1_max =  0.693
# time:  143.43
# ----------
# 14/96
# Embedding (max_top_words=500, max_opinion_length=50, embedding_vector_lengths=400, units=64, epochs=10, nobs=0)
# train_f1_curr =  0.727
# train_f1_max =  0.729
# val_f1_curr =  0.69
# val_f1_max =  0.693
# time:  192.28
# ----------
# 15/96
# Embedding (max_top_words=500, max_opinion_length=50, embedding_vector_lengths=500, units=32, epochs=10, nobs=0)
# train_f1_curr =  0.732
# train_f1_max =  0.732
# val_f1_curr =  0.654
# val_f1_max =  0.655
# time:  155.93
# ----------
# 16/96
# Embedding (max_top_words=500, max_opinion_length=50, embedding_vector_lengths=500, units=64, epochs=10, nobs=0)
# train_f1_curr =  0.729
# train_f1_max =  0.729
# val_f1_curr =  0.674
# val_f1_max =  0.682
# time:  204.42
# ----------
# 17/96
# Embedding (max_top_words=500, max_opinion_length=50, embedding_vector_lengths=400, units=32, epochs=10, nobs=1)
# train_f1_curr =  0.733
# train_f1_max =  0.733
# val_f1_curr =  0.721
# val_f1_max =  0.721
# time:  265.52
# ----------
# 18/96
# Embedding (max_top_words=500, max_opinion_length=50, embedding_vector_lengths=400, units=64, epochs=10, nobs=1)
# train_f1_curr =  0.744
# train_f1_max =  0.744
# val_f1_curr =  0.756
# val_f1_max =  0.756
# time:  343.4
# ----------
# 19/96
# Embedding (max_top_words=500, max_opinion_length=50, embedding_vector_lengths=500, units=32, epochs=10, nobs=1)
# train_f1_curr =  0.734
# train_f1_max =  0.734
# val_f1_curr =  0.744
# val_f1_max =  0.744
# time:  289.64
# ----------
# 20/96
# Embedding (max_top_words=500, max_opinion_length=50, embedding_vector_lengths=500, units=64, epochs=10, nobs=1)
# train_f1_curr =  0.745
# train_f1_max =  0.745
# val_f1_curr =  0.742
# val_f1_max =  0.744
# time:  375.33
# ----------
# 21/96
# Embedding (max_top_words=500, max_opinion_length=50, embedding_vector_lengths=400, units=32, epochs=10, nobs=2)
# train_f1_curr =  0.737
# train_f1_max =  0.737
# val_f1_curr =  0.751
# val_f1_max =  0.751
# time:  444.5
# ----------
# 22/96
# Embedding (max_top_words=500, max_opinion_length=50, embedding_vector_lengths=400, units=64, epochs=10, nobs=2)
# train_f1_curr =  0.736
# train_f1_max =  0.736
# val_f1_curr =  0.748
# val_f1_max =  0.748
# time:  589.83
# ----------
# 23/96
# Embedding (max_top_words=500, max_opinion_length=50, embedding_vector_lengths=500, units=32, epochs=10, nobs=2)
# train_f1_curr =  0.734
# train_f1_max =  0.734
# val_f1_curr =  0.723
# val_f1_max =  0.723
# time:  472.17
# ----------
# 24/96
# Embedding (max_top_words=500, max_opinion_length=50, embedding_vector_lengths=500, units=64, epochs=10, nobs=2)
# train_f1_curr =  0.74
# train_f1_max =  0.741
# val_f1_curr =  0.758
# val_f1_max =  0.758
# time:  620.06
# ----------
# 25/96
# Embedding (max_top_words=500, max_opinion_length=40, embedding_vector_lengths=400, units=32, epochs=10, nobs=0)
# train_f1_curr =  0.731
# train_f1_max =  0.731
# val_f1_curr =  0.672
# val_f1_max =  0.686
# time:  118.67
# ----------
# 26/96
# Embedding (max_top_words=500, max_opinion_length=40, embedding_vector_lengths=400, units=64, epochs=10, nobs=0)
# train_f1_curr =  0.737
# train_f1_max =  0.737
# val_f1_curr =  0.71
# val_f1_max =  0.71
# time:  151.92
# ----------
# 27/96
# Embedding (max_top_words=500, max_opinion_length=40, embedding_vector_lengths=500, units=32, epochs=10, nobs=0)
# train_f1_curr =  0.726
# train_f1_max =  0.726
# val_f1_curr =  0.68
# val_f1_max =  0.69
# time:  129.49
# ----------
# 28/96
# Embedding (max_top_words=500, max_opinion_length=40, embedding_vector_lengths=500, units=64, epochs=10, nobs=0)
# train_f1_curr =  0.733
# train_f1_max =  0.733
# val_f1_curr =  0.699
# val_f1_max =  0.699
# time:  168.23
# ----------
# 29/96
# Embedding (max_top_words=500, max_opinion_length=40, embedding_vector_lengths=400, units=32, epochs=10, nobs=1)
# train_f1_curr =  0.729
# train_f1_max =  0.729
# val_f1_curr =  0.725
# val_f1_max =  0.725
# time:  231.7
# ----------
# 30/96
# Embedding (max_top_words=500, max_opinion_length=40, embedding_vector_lengths=400, units=64, epochs=10, nobs=1)
# train_f1_curr =  0.726
# train_f1_max =  0.726
# val_f1_curr =  0.713
# val_f1_max =  0.713
# time:  288.85
# ----------
# 31/96
# Embedding (max_top_words=500, max_opinion_length=40, embedding_vector_lengths=500, units=32, epochs=10, nobs=1)
# train_f1_curr =  0.732
# train_f1_max =  0.732
# val_f1_curr =  0.724
# val_f1_max =  0.724
# time:  254.09
# ----------
# 32/96
# Embedding (max_top_words=500, max_opinion_length=40, embedding_vector_lengths=500, units=64, epochs=10, nobs=1)
# train_f1_curr =  0.735
# train_f1_max =  0.735
# val_f1_curr =  0.736
# val_f1_max =  0.736
# time:  309.24
# ----------
# 33/96
# Embedding (max_top_words=500, max_opinion_length=40, embedding_vector_lengths=400, units=32, epochs=10, nobs=2)
# train_f1_curr =  0.714
# train_f1_max =  0.714
# val_f1_curr =  0.701
# val_f1_max =  0.701
# time:  361.01
# ----------
# 34/96
# Embedding (max_top_words=500, max_opinion_length=40, embedding_vector_lengths=400, units=64, epochs=10, nobs=2)
# train_f1_curr =  0.73
# train_f1_max =  0.736
# val_f1_curr =  0.73
# val_f1_max =  0.733
# time:  473.89
# ----------
# 35/96
# Embedding (max_top_words=500, max_opinion_length=40, embedding_vector_lengths=500, units=32, epochs=10, nobs=2)
# train_f1_curr =  0.733
# train_f1_max =  0.733
# val_f1_curr =  0.731
# val_f1_max =  0.731
# time:  388.4
# ----------
# 36/96
# Embedding (max_top_words=500, max_opinion_length=40, embedding_vector_lengths=500, units=64, epochs=10, nobs=2)
# train_f1_curr =  0.736
# train_f1_max =  0.738
# val_f1_curr =  0.73
# val_f1_max =  0.74
# time:  507.37
# ----------
# 37/96
# Embedding (max_top_words=500, max_opinion_length=10, embedding_vector_lengths=400, units=32, epochs=10, nobs=0)
# train_f1_curr =  0.617
# train_f1_max =  0.617
# val_f1_curr =  0.533
# val_f1_max =  0.542
# time:  44.57
# ----------
# 38/96
# Embedding (max_top_words=500, max_opinion_length=10, embedding_vector_lengths=400, units=64, epochs=10, nobs=0)
# train_f1_curr =  0.633
# train_f1_max =  0.633
# val_f1_curr =  0.543
# val_f1_max =  0.543
# time:  50.39
# ----------
# 39/96
# Embedding (max_top_words=500, max_opinion_length=10, embedding_vector_lengths=500, units=32, epochs=10, nobs=0)
# train_f1_curr =  0.629
# train_f1_max =  0.629
# val_f1_curr =  0.528
# val_f1_max =  0.531
# time:  46.03
# ----------
# 40/96
# Embedding (max_top_words=500, max_opinion_length=10, embedding_vector_lengths=500, units=64, epochs=10, nobs=0)
# train_f1_curr =  0.631
# train_f1_max =  0.631
# val_f1_curr =  0.546
# val_f1_max =  0.546
# time:  54.9
# ----------
# 41/96
# Embedding (max_top_words=500, max_opinion_length=10, embedding_vector_lengths=400, units=32, epochs=10, nobs=1)
# train_f1_curr =  0.585
# train_f1_max =  0.589
# val_f1_curr =  0.53
# val_f1_max =  0.53
# time:  72.78
# ----------
# 42/96
# Embedding (max_top_words=500, max_opinion_length=10, embedding_vector_lengths=400, units=64, epochs=10, nobs=1)
# train_f1_curr =  0.595
# train_f1_max =  0.595
# val_f1_curr =  0.531
# val_f1_max =  0.535
# time:  89.98
# ----------
# 43/96
# Embedding (max_top_words=500, max_opinion_length=10, embedding_vector_lengths=500, units=32, epochs=10, nobs=1)
# train_f1_curr =  0.611
# train_f1_max =  0.612
# val_f1_curr =  0.53
# val_f1_max =  0.536
# time:  80.81
# ----------
# 44/96
# Embedding (max_top_words=500, max_opinion_length=10, embedding_vector_lengths=500, units=64, epochs=10, nobs=1)
# train_f1_curr =  0.593
# train_f1_max =  0.603
# val_f1_curr =  0.52
# val_f1_max =  0.533
# time:  97.7
# ----------
# 45/96
# Embedding (max_top_words=500, max_opinion_length=10, embedding_vector_lengths=400, units=32, epochs=10, nobs=2)
# train_f1_curr =  0.587
# train_f1_max =  0.587
# val_f1_curr =  0.523
# val_f1_max =  0.523
# time:  115.52
# ----------
# 46/96
# Embedding (max_top_words=500, max_opinion_length=10, embedding_vector_lengths=400, units=64, epochs=10, nobs=2)
# train_f1_curr =  0.59
# train_f1_max =  0.59
# val_f1_curr =  0.516
# val_f1_max =  0.534
# time:  151.06
# ----------
# 47/96
# Embedding (max_top_words=500, max_opinion_length=10, embedding_vector_lengths=500, units=32, epochs=10, nobs=2)
# train_f1_curr =  0.597
# train_f1_max =  0.597
# val_f1_curr =  0.52
# val_f1_max =  0.537
# time:  130.87
# ----------
# 48/96
# Embedding (max_top_words=500, max_opinion_length=10, embedding_vector_lengths=500, units=64, epochs=10, nobs=2)
# train_f1_curr =  0.598
# train_f1_max =  0.598
# val_f1_curr =  0.53
# val_f1_max =  0.538
# time:  195.57
# ----------
# 49/96
# Embedding (max_top_words=300, max_opinion_length=60, embedding_vector_lengths=400, units=32, epochs=10, nobs=0)
# train_f1_curr =  0.67
# train_f1_max =  0.67
# val_f1_curr =  0.652
# val_f1_max =  0.652
# time:  221.48
# ----------
# 50/96
# Embedding (max_top_words=300, max_opinion_length=60, embedding_vector_lengths=400, units=64, epochs=10, nobs=0)
# train_f1_curr =  0.694
# train_f1_max =  0.694
# val_f1_curr =  0.67
# val_f1_max =  0.67
# time:  255.18
# ----------
# 51/96
# Embedding (max_top_words=300, max_opinion_length=60, embedding_vector_lengths=500, units=32, epochs=10, nobs=0)
# train_f1_curr =  0.663
# train_f1_max =  0.663
# val_f1_curr =  0.615
# val_f1_max =  0.643
# time:  270.69
# ----------
# 52/96
# Embedding (max_top_words=300, max_opinion_length=60, embedding_vector_lengths=500, units=64, epochs=10, nobs=0)
# train_f1_curr =  0.691
# train_f1_max =  0.691
# val_f1_curr =  0.668
# val_f1_max =  0.67
# time:  256.38
# ----------
# 53/96
# Embedding (max_top_words=300, max_opinion_length=60, embedding_vector_lengths=400, units=32, epochs=10, nobs=1)
# train_f1_curr =  0.699
# train_f1_max =  0.705
# val_f1_curr =  0.746
# val_f1_max =  0.746
# time:  366.92
# ----------
# 54/96
# Embedding (max_top_words=300, max_opinion_length=60, embedding_vector_lengths=400, units=64, epochs=10, nobs=1)
# train_f1_curr =  0.714
# train_f1_max =  0.714
# val_f1_curr =  0.758
# val_f1_max =  0.758
# time:  416.0
# ----------
# 55/96
# Embedding (max_top_words=300, max_opinion_length=60, embedding_vector_lengths=500, units=32, epochs=10, nobs=1)
# train_f1_curr =  0.694
# train_f1_max =  0.697
# val_f1_curr =  0.704
# val_f1_max =  0.706
# time:  392.46
# ----------
# 56/96
# Embedding (max_top_words=300, max_opinion_length=60, embedding_vector_lengths=500, units=64, epochs=10, nobs=1)
# train_f1_curr =  0.709
# train_f1_max =  0.709
# val_f1_curr =  0.721
# val_f1_max =  0.721
# time:  626.9
# ----------
# 57/96
# Embedding (max_top_words=300, max_opinion_length=60, embedding_vector_lengths=400, units=32, epochs=10, nobs=2)
# train_f1_curr =  0.707
# train_f1_max =  0.707
# val_f1_curr =  0.754
# val_f1_max =  0.754
# time:  676.53
# ----------
# 58/96
# Embedding (max_top_words=300, max_opinion_length=60, embedding_vector_lengths=400, units=64, epochs=10, nobs=2)
# train_f1_curr =  0.716
# train_f1_max =  0.716
# val_f1_curr =  0.749
# val_f1_max =  0.751
# time:  707.68
# ----------
# 59/96
# Embedding (max_top_words=300, max_opinion_length=60, embedding_vector_lengths=500, units=32, epochs=10, nobs=2)
# train_f1_curr =  0.708
# train_f1_max =  0.71
# val_f1_curr =  0.738
# val_f1_max =  0.738
# time:  997.56
# ----------
# 60/96
# Embedding (max_top_words=300, max_opinion_length=60, embedding_vector_lengths=500, units=64, epochs=10, nobs=2)
# train_f1_curr =  0.72
# train_f1_max =  0.72
# val_f1_curr =  0.756
# val_f1_max =  0.756
# time:  757.08
# ----------
# 61/96
# Embedding (max_top_words=300, max_opinion_length=50, embedding_vector_lengths=400, units=32, epochs=10, nobs=0)
# train_f1_curr =  0.692
# train_f1_max =  0.692
# val_f1_curr =  0.669
# val_f1_max =  0.669
# time:  147.0
# ----------
# 62/96
# Embedding (max_top_words=300, max_opinion_length=50, embedding_vector_lengths=400, units=64, epochs=10, nobs=0)
# train_f1_curr =  0.704
# train_f1_max =  0.704
# val_f1_curr =  0.661
# val_f1_max =  0.674
# time:  191.55
# ----------
# 63/96
# Embedding (max_top_words=300, max_opinion_length=50, embedding_vector_lengths=500, units=32, epochs=10, nobs=0)
# train_f1_curr =  0.698
# train_f1_max =  0.703
# val_f1_curr =  0.662
# val_f1_max =  0.662
# time:  159.5
# ----------
# 64/96
# Embedding (max_top_words=300, max_opinion_length=50, embedding_vector_lengths=500, units=64, epochs=10, nobs=0)
# train_f1_curr =  0.705
# train_f1_max =  0.705
# val_f1_curr =  0.673
# val_f1_max =  0.689
# time:  205.15
# ----------
# 65/96
# Embedding (max_top_words=300, max_opinion_length=50, embedding_vector_lengths=400, units=32, epochs=10, nobs=1)
# train_f1_curr =  0.705
# train_f1_max =  0.705
# val_f1_curr =  0.693
# val_f1_max =  0.693
# time:  271.34
# ----------
# 66/96
# Embedding (max_top_words=300, max_opinion_length=50, embedding_vector_lengths=400, units=64, epochs=10, nobs=1)
# train_f1_curr =  0.717
# train_f1_max =  0.717
# val_f1_curr =  0.74
# val_f1_max =  0.745
# time:  349.09
# ----------
# 67/96
# Embedding (max_top_words=300, max_opinion_length=50, embedding_vector_lengths=500, units=32, epochs=10, nobs=1)
# train_f1_curr =  0.71
# train_f1_max =  0.71
# val_f1_curr =  0.717
# val_f1_max =  0.717
# time:  302.16
# ----------
# 68/96
# Embedding (max_top_words=300, max_opinion_length=50, embedding_vector_lengths=500, units=64, epochs=10, nobs=1)
# train_f1_curr =  0.711
# train_f1_max =  0.711
# val_f1_curr =  0.741
# val_f1_max =  0.741
# time:  387.01
# ----------
# 69/96
# Embedding (max_top_words=300, max_opinion_length=50, embedding_vector_lengths=400, units=32, epochs=10, nobs=2)
# train_f1_curr =  0.71
# train_f1_max =  0.71
# val_f1_curr =  0.737
# val_f1_max =  0.737
# time:  598.28
# ----------
# 70/96
# Embedding (max_top_words=300, max_opinion_length=50, embedding_vector_lengths=400, units=64, epochs=10, nobs=2)
# train_f1_curr =  0.71
# train_f1_max =  0.71
# val_f1_curr =  0.746
# val_f1_max =  0.746
# time:  954.74
# ----------
# 71/96
# Embedding (max_top_words=300, max_opinion_length=50, embedding_vector_lengths=500, units=32, epochs=10, nobs=2)
# train_f1_curr =  0.726
# train_f1_max =  0.726
# val_f1_curr =  0.751
# val_f1_max =  0.751
# time:  1014.95
# ----------
# 72/96
# Embedding (max_top_words=300, max_opinion_length=50, embedding_vector_lengths=500, units=64, epochs=10, nobs=2)
# train_f1_curr =  0.724
# train_f1_max =  0.724
# val_f1_curr =  0.762
# val_f1_max =  0.762
# time:  935.67
# ----------
# 73/96
# Embedding (max_top_words=300, max_opinion_length=40, embedding_vector_lengths=400, units=32, epochs=10, nobs=0)
# train_f1_curr =  0.704
# train_f1_max =  0.704
# val_f1_curr =  0.682
# val_f1_max =  0.682
# time:  131.06
# ----------
# 74/96
# Embedding (max_top_words=300, max_opinion_length=40, embedding_vector_lengths=400, units=64, epochs=10, nobs=0)
# train_f1_curr =  0.707
# train_f1_max =  0.707
# val_f1_curr =  0.679
# val_f1_max =  0.679
# time:  154.8
# ----------
# 75/96
# Embedding (max_top_words=300, max_opinion_length=40, embedding_vector_lengths=500, units=32, epochs=10, nobs=0)
# train_f1_curr =  0.708
# train_f1_max =  0.709
# val_f1_curr =  0.681
# val_f1_max =  0.681
# time:  134.46
# ----------
# 76/96
# Embedding (max_top_words=300, max_opinion_length=40, embedding_vector_lengths=500, units=64, epochs=10, nobs=0)
# train_f1_curr =  0.713
# train_f1_max =  0.713
# val_f1_curr =  0.665
# val_f1_max =  0.681
# time:  163.78
# ----------
# 77/96
# Embedding (max_top_words=300, max_opinion_length=40, embedding_vector_lengths=400, units=32, epochs=10, nobs=1)
# train_f1_curr =  0.708
# train_f1_max =  0.708
# val_f1_curr =  0.714
# val_f1_max =  0.723
# time:  242.18
# ----------
# 78/96
# Embedding (max_top_words=300, max_opinion_length=40, embedding_vector_lengths=400, units=64, epochs=10, nobs=1)
# train_f1_curr =  0.721
# train_f1_max =  0.721
# val_f1_curr =  0.73
# val_f1_max =  0.731
# time:  284.64
# ----------
# 79/96
# Embedding (max_top_words=300, max_opinion_length=40, embedding_vector_lengths=500, units=32, epochs=10, nobs=1)
# train_f1_curr =  0.709
# train_f1_max =  0.709
# val_f1_curr =  0.736
# val_f1_max =  0.736
# time:  246.43
# ----------
# 80/96
# Embedding (max_top_words=300, max_opinion_length=40, embedding_vector_lengths=500, units=64, epochs=10, nobs=1)
# train_f1_curr =  0.715
# train_f1_max =  0.715
# val_f1_curr =  0.743
# val_f1_max =  0.743
# time:  311.41
# ----------
# 81/96
# Embedding (max_top_words=300, max_opinion_length=40, embedding_vector_lengths=400, units=32, epochs=10, nobs=2)
# train_f1_curr =  0.702
# train_f1_max =  0.702
# val_f1_curr =  0.717
# val_f1_max =  0.717
# time:  365.94
# ----------
# 82/96
# Embedding (max_top_words=300, max_opinion_length=40, embedding_vector_lengths=400, units=64, epochs=10, nobs=2)
# train_f1_curr =  0.716
# train_f1_max =  0.716
# val_f1_curr =  0.745
# val_f1_max =  0.748
# time:  482.42
# ----------
# 83/96
# Embedding (max_top_words=300, max_opinion_length=40, embedding_vector_lengths=500, units=32, epochs=10, nobs=2)
# train_f1_curr =  0.72
# train_f1_max =  0.72
# val_f1_curr =  0.748
# val_f1_max =  0.756
# time:  391.43
# ----------
# 84/96
# Embedding (max_top_words=300, max_opinion_length=40, embedding_vector_lengths=500, units=64, epochs=10, nobs=2)
# train_f1_curr =  0.717
# train_f1_max =  0.717
# val_f1_curr =  0.738
# val_f1_max =  0.741
# time:  538.65
# ----------
# 85/96
# Embedding (max_top_words=300, max_opinion_length=10, embedding_vector_lengths=400, units=32, epochs=10, nobs=0)
# train_f1_curr =  0.59
# train_f1_max =  0.599
# val_f1_curr =  0.501
# val_f1_max =  0.501
# time:  43.18
# ----------
# 86/96
# Embedding (max_top_words=300, max_opinion_length=10, embedding_vector_lengths=400, units=64, epochs=10, nobs=0)
# train_f1_curr =  0.598
# train_f1_max =  0.598
# val_f1_curr =  0.506
# val_f1_max =  0.513
# time:  53.71
# ----------
# 87/96
# Embedding (max_top_words=300, max_opinion_length=10, embedding_vector_lengths=500, units=32, epochs=10, nobs=0)
# train_f1_curr =  0.608
# train_f1_max =  0.608
# val_f1_curr =  0.504
# val_f1_max =  0.504
# time:  45.52
# ----------
# 88/96
# Embedding (max_top_words=300, max_opinion_length=10, embedding_vector_lengths=500, units=64, epochs=10, nobs=0)
# train_f1_curr =  0.606
# train_f1_max =  0.61
# val_f1_curr =  0.519
# val_f1_max =  0.519
# time:  71.61
# ----------
# 89/96
# Embedding (max_top_words=300, max_opinion_length=10, embedding_vector_lengths=400, units=32, epochs=10, nobs=1)
# train_f1_curr =  0.57
# train_f1_max =  0.574
# val_f1_curr =  0.496
# val_f1_max =  0.498
# time:  74.9
# ----------
# 90/96
# Embedding (max_top_words=300, max_opinion_length=10, embedding_vector_lengths=400, units=64, epochs=10, nobs=1)
# train_f1_curr =  0.567
# train_f1_max =  0.572
# val_f1_curr =  0.495
# val_f1_max =  0.497
# time:  90.84
# ----------
# 91/96
# Embedding (max_top_words=300, max_opinion_length=10, embedding_vector_lengths=500, units=32, epochs=10, nobs=1)
# train_f1_curr =  0.568
# train_f1_max =  0.568
# val_f1_curr =  0.508
# val_f1_max =  0.509
# time:  82.41
# ----------
# 92/96
# Embedding (max_top_words=300, max_opinion_length=10, embedding_vector_lengths=500, units=64, epochs=10, nobs=1)
# train_f1_curr =  0.58
# train_f1_max =  0.58
# val_f1_curr =  0.514
# val_f1_max =  0.514
# time:  99.75
# ----------
# 93/96
# Embedding (max_top_words=300, max_opinion_length=10, embedding_vector_lengths=400, units=32, epochs=10, nobs=2)
# train_f1_curr =  0.566
# train_f1_max =  0.566
# val_f1_curr =  0.502
# val_f1_max =  0.506
# time:  121.47
# ----------
# 94/96
# Embedding (max_top_words=300, max_opinion_length=10, embedding_vector_lengths=400, units=64, epochs=10, nobs=2)
# train_f1_curr =  0.562
# train_f1_max =  0.562
# val_f1_curr =  0.505
# val_f1_max =  0.515
# time:  153.44
# ----------
# 95/96
# Embedding (max_top_words=300, max_opinion_length=10, embedding_vector_lengths=500, units=32, epochs=10, nobs=2)
# train_f1_curr =  0.577
# train_f1_max =  0.578
# val_f1_curr =  0.522
# val_f1_max =  0.525
# time:  128.77
# ----------
# 96/96
# Embedding (max_top_words=300, max_opinion_length=10, embedding_vector_lengths=500, units=64, epochs=10, nobs=2)
# train_f1_curr =  0.57
# train_f1_max =  0.57
# val_f1_curr =  0.516
# val_f1_max =  0.516
# time:  164.54
# ----------
# ==========
# Start of experiment: 2021-10-09 10:52:41.163633
# End of experiment: 2021-10-09 19:07:39.831360
# Experiment took:
#     0 days
#     8 hours
#     14 minutes
#     58 seconds

# %%
dfruns.to_csv('LSTM_X_prep.csv')

# %%
# !mlflow ui --backend-store-uri /home/jovyan/nlp2/shared-mlruns/team-three/mariusz --default-artifact-root /home/jovyan/nlp2/shared-mlruns/team-three/mariusz --port 5001
# Out:
# [2021-10-09 19:13:45 +0000] [3604] [INFO] Starting gunicorn 20.1.0
# [2021-10-09 19:13:45 +0000] [3604] [INFO] Listening at: http://127.0.0.1:5001 (3604)
# [2021-10-09 19:13:45 +0000] [3604] [INFO] Using worker: sync
# [2021-10-09 19:13:45 +0000] [3606] [INFO] Booting worker with pid: 3606
# ^C
# [2021-10-09 19:25:59 +0000] [3604] [INFO] Handling signal: int
# [2021-10-09 19:25:59 +0000] [3606] [INFO] Worker exiting (pid: 3606)

# %%
# !mlflow ui
# Out:
# [2021-10-05 17:25:19 +0000] [677] [INFO] Starting gunicorn 20.1.0
# [2021-10-05 17:25:19 +0000] [677] [INFO] Listening at: http://127.0.0.1:5000 (677)
# [2021-10-05 17:25:19 +0000] [677] [INFO] Using worker: sync
# [2021-10-05 17:25:19 +0000] [679] [INFO] Booting worker with pid: 679
# ^C
# [2021-10-05 17:26:37 +0000] [677] [INFO] Handling signal: int
# [2021-10-05 17:26:37 +0000] [679] [INFO] Worker exiting (pid: 679)
